# %%
import pandas as pd

# %%
df = pd.read_csv("data_cleaned.csv")

# %%
df.head()
# Out:
#        ID               Name  Age      Value    Wage Preferred_Foot  \
# 0  158023           L. Messi   31  110500000  565000           Left
# 1   20801  Cristiano Ronaldo   33   77000000  405000          Right
# 2  190871          Neymar Jr   26  118500000  290000          Right
# 3  192985       K. De Bruyne   27  102000000  355000          Right
# 4  183277          E. Hazard   27   93000000  340000          Right
#
#    Weak_Foot  Trick_Skills       Work_Rate Position  ...  Penalties Composure  \
# 0          4             4  Medium/ Medium       RF  ...         75        96
# 1          4             5       High/ Low       ST  ...         85        95
# 2          5             5    High/ Medium       LW  ...         81        94
# 3          5             4      High/ High      RCM  ...         79        88
# 4          4             4    High/ Medium       LF  ...         86        91
#
#    Marking  StandingTackle  SlidingTackle  Work_Rate_A  Work_Rate_D  \
# ...

# %%
duplicateRowsDF = df[df.duplicated(['ID'])]

# %%
print(duplicateRowsDF)
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Value, Wage, Preferred_Foot, Weak_Foot, Trick_Skills, Work_Rate, Position, Jersey_Number, Contract_Valid_Until, Height, Weight, Striker, CentralMidfielder, SideMidfielder, WingBack, CenterBack, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FreeKickAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, Work_Rate_A, Work_Rate_D, Position_cat, Basic_Player, Position_Stat]
# Index: []
#
# [0 rows x 52 columns]
